# %%
import pandas as pd

df = pd.read_csv("samples_geocoded.csv")

null_counts = df.isnull().sum()

# %%
df
# Out:
#                                  DOI                            Sample_ID  \
# 0       10.1016/j.watres.2017.11.011       1|10.1016/j.watres.2017.11.011
# 1       10.1016/j.watres.2017.11.011       2|10.1016/j.watres.2017.11.011
# 2       10.1016/j.watres.2017.11.011       3|10.1016/j.watres.2017.11.011
# 3       10.1016/j.watres.2017.11.011       4|10.1016/j.watres.2017.11.011
# 4                 10.1039/c6ay01184e                 1|10.1039/c6ay01184e
# ..                               ...                                  ...
# 602  10.1016/j.scitotenv.2021.148001  Spr|10.1016/j.scitotenv.2021.148001
# 603  10.1016/j.scitotenv.2021.148001  Sum|10.1016/j.scitotenv.2021.148001
# 604  10.1016/j.scitotenv.2021.148001  Aut|10.1016/j.scitotenv.2021.148001
# 605  10.1016/j.scitotenv.2021.148001  Win|10.1016/j.scitotenv.2021.148001
# 606  10.1016/j.scitotenv.2022.154015    1|10.1016/j.scitotenv.2022.154015
#
#     Subsample_ID                                       Location    Countries  \
# ...

# %%
null_counts = df.isna().sum()/df.shape[0]
for n in null_counts:
    print(n)
# Out:
# 0
# 0
# 473
# 149
# 149
# 0
# 6
# 6
# 592
# 590
# 592
# 607
# 607
# 607
# 588
# 603
# 606
# 593
# 593
# 564
# 449
# 458
# 517
# 605
# 503
# 557
# 557
# 601
# 601
# 486
# 604
# 604
# 597
# 603
# 601
# 605
# 602
# 593
# 600
# 525
# 606
# 602
# 569
# 568
# 606
# 602
# 606
# 606
# 606
# 606
# 599
# 603
# 606
# 606
# 606
# 606
# 606
# 602
# 605
# 604
# 602
# 604
# 606
# 606
# 605
# 606
# 606
# 473
# 466
# 564
# 571
# 565
# 576
# 606
# 606
# 592
# 606
# 607
# 607
# 593
# 599
# 593
# 575
# 593
# 607
# 603
# 603
# 577
# 593
# 606
# 593
# 607
# 603
# 605
# 606
# 566
# 602
# 590
# 603
# 562
# 605
# 602
# 607
# 547
# 606
# 604
# 604
# 605
# 604
# 597
# 597
# 607
# 606
# 155
# 155

# %%
df.shape
# Out:
# (607, 115)

# %%
micro_df = pd.read_csv("Merged_Microplastic_Data.csv")
micro_df.isna().sum()/micro_df.shape[0]
# Out:
# Unnamed: 0                              0.000000
# DOI                                     0.000000
# Sample_ID                               0.000000
# Location                                0.245470
# Countries                               0.245470
# Source                                  0.000000
# Concentration                           0.009885
# Concentration_Units                     0.009885
# Approximate_Latitude                    0.255354
# Approximate_Longitude                   0.255354
# Sample_device_and_deployment_methods    0.034596
# Digestion                               0.034596
# Filtration                              0.034596
# Filter_Size                             0.034596
# Microplastic_Identification_Method      0.034596
# Spectral_Analysis                       0.034596
# Controls                                0.034596
# dtype: float64

# %%
micro_df.shape
# Out:
# (607, 17)

# %%
micro_df.columns
# Out:
# Index(['Unnamed: 0', 'DOI', 'Sample_ID', 'Location', 'Countries', 'Source',
#        'Concentration', 'Concentration_Units', 'Approximate_Latitude',
#        'Approximate_Longitude', 'Sample_device_and_deployment_methods',
#        'Digestion', 'Filtration', 'Filter_Size',
#        'Microplastic_Identification_Method', 'Spectral_Analysis', 'Controls'],
#       dtype='object')

# %%
micro_df[["Location", "Countries", "Source"]]
# Out:
#                                           Location    Countries         Source
# 0                                          Germany      Germany  bottled water
# 1                                          Germany      Germany  bottled water
# 2                                          Germany      Germany  bottled water
# 3                                          Germany      Germany  bottled water
# 4                                          Germany      Germany  bottled water
# ..                                             ...          ...            ...
# 602  South-to-North Water Diversion Project, China        China      tap water
# 603  South-to-North Water Diversion Project, China        China      tap water
# 604  South-to-North Water Diversion Project, China        China      tap water
# 605  South-to-North Water Diversion Project, China        China      tap water
# 606                                    South Korea  South Korea      tap water
#
# [607 rows x 3 columns]

# %%
len(micro_df["Countries"].unique())
# Out:
# 42

# %%
micro_df[micro_df["Countries"] == "USA"].shape
# Out:
# (34, 17)
